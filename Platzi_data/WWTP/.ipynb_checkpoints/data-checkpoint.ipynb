# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import math
from matplotlib.offsetbox import AnchoredText
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
from IPython.display import display
import seaborn as sns
from sklearn.datasets import load_iris

# %%
df = pd.read_csv("China_WWTP_Data.csv")
df
df = df.set_index('DATE')
df = df.dropna()
df_corr = df.corr()
df_corr_abs = df.corr().abs()
upper = df_corr_abs.where(np.triu(np.ones(df_corr_abs.shape), k=1).astype(np.bool))
df_corr.to_csv(r'correlation.csv')

# %%
df
# Out:
#            Fw_to_EQ  Fw_EQ_to_BIO  Fw_to_BIO  Fw_efl  EQ_COD  BT_N_COD  \
# DATE
# 1/2/2019       92.0         292.0      564.0   227.0   345.0      46.0
# 1/4/2019      135.0         285.0      563.0   295.0   410.0      14.0
# 1/6/2019      142.0         324.0      561.0   314.0   354.0      38.0
# 1/9/2019      130.0         325.0      562.0   314.0   364.0      18.0
# 1/11/2019     129.0         324.0      562.0   306.0   313.0      30.0
# 1/13/2019     111.0         304.0      558.0   298.0   312.0      34.0
# 1/14/2019     105.0         297.0      561.0   192.0   348.0      38.0
# 1/16/2019      42.0         152.0      562.0   197.0   377.0      22.0
# 1/18/2019      53.0         240.0      115.0   246.0   395.0      57.0
# 1/20/2019      53.0         287.0      564.0   305.0   367.0      14.0
# 1/21/2019      56.0         306.0      557.0   254.0   328.0      37.0
# 1/23/2019      55.0         312.0      558.0   290.0   379.0      34.0
# 1/25/2019      40.0         297.0      541.0   294.0   321.0      41.0
# 1/27/2019      42.0         306.0      558.0   309.0   321.0      57.0
# 1/28/2019      41.0         305.0      561.0   296.0   353.0      25.0
# 1/30/2019      35.0         269.0      564.0   302.0   355.0      24.0
# 2/1/2019      242.0         262.0      522.0   264.0   359.0      28.0
# 2/8/2019      180.0         154.0      551.0   209.0   376.0      28.0
# 2/10/2019     260.0         264.0      540.0   280.0   342.0      31.0
# 2/11/2019     283.0         286.0      553.0   289.0   319.0      47.0
# 2/13/2019     302.0         300.0      560.0   299.0   359.0      23.0
# 2/15/2019     291.0         301.0      546.0   294.0   387.0      30.0
# 2/17/2019     296.0         307.0      532.0   302.0   387.0      18.0
# 2/18/2019     297.0         307.0      506.0   298.0   354.0      51.0
#
#            D_COD_ON  BT_C_MLSS  BT_C_MVLSS  BT_N_MLSS  ...  OxT_PH_AM  \
# DATE                                                   ...
# 1/2/2019      164.0     6400.0      5300.0     7100.0  ...       3.85
# 1/4/2019      119.0     7700.0      7000.0     6600.0  ...       3.84
# 1/6/2019      140.0     6900.0      5900.0     6700.0  ...       3.76
# 1/9/2019      144.0     7000.0      6100.0     5900.0  ...       3.75
# 1/11/2019     149.0     5900.0      5100.0     6300.0  ...       3.82
# 1/13/2019      99.0     5800.0      5600.0     8800.0  ...       3.65
# 1/14/2019     116.0     6400.0      5700.0     6700.0  ...       3.65
# 1/16/2019     110.0     7600.0      6900.0     6500.0  ...       3.59
# 1/18/2019     121.0     6500.0      5900.0     6300.0  ...       3.67
# 1/20/2019     121.0     8000.0      7400.0     5900.0  ...       3.44
# 1/21/2019      96.0     5800.0      5700.0     5800.0  ...       3.68
# 1/23/2019     144.0     6100.0      5500.0     5800.0  ...       3.70
# 1/25/2019     142.0     5900.0      5800.0     6600.0  ...       3.60
# 1/20/2019    0,00275
# 1/21/2019    0,00649
# 1/23/2019    0,00654
# 1/25/2019    0,00631
# 1/27/2019    0,01163
# 1/28/2019    0,00424
# 1/30/2019    0,00471
# 2/1/2019     0,00651
# 2/8/2019     0,00509
# 2/10/2019    0,00525
# 2/11/2019    0,00825
# 2/13/2019    0,00442
# 2/15/2019    0,00566
# 2/17/2019    0,00340
# 2/18/2019    0,00981
#
# [24 rows x 26 columns]

# %%
#sns.pairplot(df)

# %%
#Saving columns and rows
columns = list(df_corr.columns)
rows = list(df_corr.index.values)

# %%
labels = [l for l in np.arange(1,len(columns)+1)]
fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111)
ax.matshow(df_corr_abs, cmap=plt.cm.RdYlGn)

ax.set_xticks(np.arange(len(labels)))
ax.set_yticks(np.arange(len(labels)))

ax.set_xticklabels(labels)
ax.set_yticklabels(labels)

plt.show()

for i in np.arange(0,len(columns)):
    print('{} = {}'.format(i+1,columns[i]))
# Out:
# 1 = Fw_to_EQ
# 2 = Fw_EQ_to_BIO
# 3 = Fw_to_BIO
# 4 = Fw_efl
# 5 = EQ_COD
# 6 = BT_N_COD
# 7 = D_COD_ON
# 8 = BT_C_MLSS
# 9 = BT_C_MVLSS
# 10 = BT_N_MLSS
# 11 = BT_N_MVLSS
# 12 = D_SS
# 13 = OxT_PH_AM
# 14 = OxT_PH_PM
# 15 = EQ_PH
# 16 = BT_N_PH
# 17 = D_PH
# 18 = BT_N_DO
# 19 = BT_C_DO

# %%
corrv=list()
th = 0.3
corr = upper.values
sz = len(corr)
for i in np.arange(0,sz):
    for j in np.arange(0,sz):        
        if corr[i,j] > th and corr[i,j] < 1:
            corrv.append([i,j])

# %%
sz = len(corrv)
values = df_corr.values
corrname = list()
print('Las variables con una correlación mayor a abs(±{}) son:'.format(th))
for i in np.arange(0, sz):
    print('    {} y {} con correlación {} '.format(rows[corrv[i][0]], columns[corrv[i][1]], round(values[corrv[i][0],corrv[i][1]], 4)))
    corrname.append([rows[corrv[i][0]], columns[corrv[i][1]]])
# Out:
# Las variables con una correlación mayor a abs(±0.3) son:
#     Fw_to_EQ y D_COD_ON con correlación -0.3642
#     Fw_to_EQ y BT_C_MLSS con correlación 0.3612
#     Fw_to_EQ y D_SS con correlación -0.331
#     Fw_to_EQ y OxT_PH_AM con correlación 0.3667
#     Fw_to_EQ y OxT_PH_PM con correlación 0.3981
#     Fw_to_EQ y EQ_PH con correlación 0.6153
#     Fw_to_EQ y D_PH con correlación -0.3571
#     Fw_to_EQ y BT_N_DO con correlación -0.3874
#     Fw_EQ_to_BIO y Fw_efl con correlación 0.69
#     Fw_EQ_to_BIO y EQ_COD con correlación -0.3366
#     Fw_EQ_to_BIO y D_COD_ON con correlación 0.477
#     Fw_EQ_to_BIO y BT_C_MLSS con correlación -0.4625
#     Fw_EQ_to_BIO y BT_C_MVLSS con correlación -0.5085
#     Fw_EQ_to_BIO y D_SS con correlación 0.5099
#     Fw_to_BIO y EQ_COD con correlación -0.3176
#     Fw_to_BIO y BT_N_COD con correlación -0.4459
#     EQ_COD y BT_N_COD con correlación -0.4097
#     EQ_COD y BT_C_MLSS con correlación 0.5974
#     EQ_COD y BT_C_MVLSS con correlación 0.5266
#     BT_N_COD y BT_C_MLSS con correlación -0.5142
#     BT_N_COD y BT_C_MVLSS con correlación -0.576
#     D_COD_ON y D_SS con correlación 0.3486
#     BT_C_MLSS y BT_C_MVLSS con correlación 0.9306
#     BT_C_MLSS y BT_N_MLSS con correlación -0.407
#     BT_C_MLSS y BT_N_MVLSS con correlación -0.463
#     BT_C_MLSS y D_SS con correlación -0.3632
#     BT_C_MLSS y OxT_PH_AM con correlación 0.4089
#     BT_C_MLSS y OxT_PH_PM con correlación 0.3026
#     BT_C_MVLSS y BT_N_MLSS con correlación -0.3745
#     BT_C_MVLSS y BT_N_MVLSS con correlación -0.318
#     BT_C_MVLSS y D_SS con correlación -0.3665
#     BT_C_MVLSS y OxT_PH_AM con correlación 0.4004
#     BT_N_MLSS y BT_N_MVLSS con correlación 0.8539
#     BT_N_MLSS y OxT_PH_AM con correlación -0.4739
#     BT_N_MLSS y OxT_PH_PM con correlación -0.4421
#     BT_N_MVLSS y OxT_PH_AM con correlación -0.4851
#     BT_N_MVLSS y OxT_PH_PM con correlación -0.3789
#     D_SS y D_PH con correlación 0.3174
#     OxT_PH_AM y OxT_PH_PM con correlación 0.4998
#     EQ_PH y D_PH con correlación -0.3794
#     EQ_PH y BT_N_DO con correlación -0.4388
#     BT_N_PH y BT_C_DO con correlación 0.3287
#     BT_N_DO y BT_C_DO con correlación 0.4016

# %%
boxes = len(corrname)

def changesize(a,b):
    fig = plt.figure(figsize = [a,b])
    b2 = 2
    b1 = boxes/b2
    b1 = int(math.ceil(b1))
    fig.subplots_adjust(hspace=0.4, wspace=0.4)
    for i in range(1, boxes + 1):
        data = pd.DataFrame(df,columns = corrname[i-1])
        ax = fig.add_subplot(b1, b2, i)
        ax.plot(data.iloc[:,0],data.iloc[:,1],'o')
        tx = str(round(values[corrv[i-1][0],corrv[i-1][1]], 4))
        tx = 'r = ' + tx
        anchored_text = AnchoredText(tx, loc=1)
        ax.add_artist(anchored_text)
        ax.set_xlabel(corrname[i-1][0])
        ax.set_ylabel(corrname[i-1][1])

a = widgets.IntSlider(min=1, max=30, value=15, description='width')
b = widgets.IntSlider(min=1, max=30, value=20, description='height')
    
widgets.interactive(changesize, a=a, b=b)
# Out:
# interactive(children=(IntSlider(value=15, description='width', max=30, min=1), IntSlider(value=20, description…

# %%
from statsmodels.tsa.stattools import adfuller

Stacionary = list()
NonStacionary = list()

for i in np.arange(0,len(columns)):
    adf_test = adfuller(df[columns[i]].dropna())
    if adf_test[0] < -3.4304633751328555 and adf_test[1] < 0.5:
        Stacionary.append(columns[i])
    else:
        NonStacionary.append(columns[i])
print('Stacionary variables are:')
for i in np.arange(0,len(Stacionary)):
    print(Stacionary[i])
print('-------------------------------------------------------------------------------------------------')
print('Non-Stacionary variables are:')
for i in np.arange(0,len(NonStacionary)):
    print(NonStacionary[i])
# Out:
# Stacionary variables are:
# Fw_to_EQ
# Fw_to_BIO
# EQ_COD
# BT_N_COD
# D_COD_ON
# BT_C_MLSS
# BT_C_MVLSS
# BT_N_MLSS
# BT_N_MVLSS
# OxT_PH_AM
# BT_N_PH
# D_PH
# BT_C_DO
# -------------------------------------------------------------------------------------------------
# Non-Stacionary variables are:
# Fw_EQ_to_BIO
# Fw_efl
# D_SS
# OxT_PH_PM
# EQ_PH
# BT_N_DO
